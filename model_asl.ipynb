# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D, Dropout

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.svm import SVC

from Models import Models, PretrainedModels

# %%
import random

random.seed(10)

# %% [markdown]
# # Carga de datos

# %%
train_data = pd.read_csv("data/asl/train.csv")
test_data = pd.read_csv("data/asl/validation.csv")

# %%
train_data.head()
# Out:
#    sequence_id target                                               file
# 0            1    yes  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 1            1    yes  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 2            1    yes  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 3            1    yes  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 4            1    yes  /Users/andreaamaya/Trabajo/megaproyecto_model/...

# %% [markdown]
# # Analisis Exploratorio

# %%
print("--------------------Train data--------------------")
print(f"Cantidad de filas : {train_data.shape[0]}")
train_letters = list(train_data.target.unique())
train_letters.sort()
print(f"Frases unicas : {train_letters}")
# Out:
# --------------------Train data--------------------
# Cantidad de filas : 12810
# Frases unicas : ['bathroom', 'cat', 'dog', 'eat food', 'father', 'fine', 'finish', 'go to', 'hello', 'help', 'learn', 'like', 'me', 'milk', 'more', 'mother', 'no', 'please', 'repeat', 'see you later', 'sign', 'thank you', 'want', 'what', 'yes']

# %%
print("--------------------Test data--------------------")
print(f"Cantidad de filas : {test_data.shape[0]}")
test_letters = list(test_data.target.unique())
test_letters.sort()
print(f"Frases unicas : {test_letters}")
# Out:
# --------------------Test data--------------------
# Cantidad de filas : 2580
# Frases unicas : ['bathroom', 'cat', 'dog', 'eat food', 'father', 'fine', 'finish', 'go to', 'hello', 'help', 'learn', 'like', 'me', 'milk', 'more', 'mother', 'no', 'please', 'repeat', 'see you later', 'sign', 'thank you', 'want', 'what', 'yes']

# %%
if (test_letters != train_letters):
    raise ValueError("Error between target and train")

# %%
train_data.describe()
# Out:
#         sequence_id
# count  12810.000000
# mean     214.000000
# std      123.268756
# min        1.000000
# 25%      107.000000
# 50%      214.000000
# 75%      321.000000
# max      427.000000

# %% [markdown]
# # Preprocesamiento del Modelo

# %% [markdown]
# Solo se obtienen 20 indices de las coordenadas x y y, ya que son las unicas que han sido altamente entrenadas del modelo mediapipe de Google

# %%
def get_needed_cols():
    cols = []

    for i in range(21):
        cols.append(f'x_Right_hand_{i}')
        cols.append(f'y_Right_hand_{i}')
        cols.append(f'x_Left_hand_{i}')
        cols.append(f'y_Left_hand_{i}')
    
    return cols

# %%
df = pd.read_csv("data/asl/data.csv")
df_test = df[df['sequence_id'].isin(test_data['sequence_id'])]
df_train = df[df['sequence_id'].isin(train_data['sequence_id'])]

# %%
print(len(df))
print(len(df_test) == len(test_data))
print(len(df_train) == len(train_data))
# Out:
# 15390
# True
# True

# %% [markdown]
# # Modelo

# %%
# Compute the lengths of the video sequences
video_lengths = df.groupby('sequence_id').size()
max_seq_length = video_lengths.max()
# max_seq_length = 30
# Plot the histogram
plt.hist(video_lengths, bins=30)  # Adjust the number of bins as needed
plt.xlabel('Video Length')
plt.ylabel('Frequency')
plt.title('Histogram of Video Lengths')
plt.show()

# %%
video_lengths.max()
# Out:
# 30

# %%
# Create a one-hot encoder
label_encoder = LabelEncoder()

# %%
def padding_labels(target):
    integer_encoded = label_encoder.fit_transform(target)
    integer_encoded = integer_encoded.reshape(-1, 1)

    # Encode the word "Hello"
    onehot_encoder = OneHotEncoder(sparse=False)  # sparse=False to get a numpy array as output
    onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
    return onehot_encoded

# %%
target_train = df_train['target'][df_train.groupby('sequence_id').cumcount() == 0].tolist()

# %%
X_train = df_train
y_train = padding_labels(target_train)
# Out:
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
del X_train["sequence_id"] 
del X_train["target"] 

print(len(X_train), len(y_train))
# Out:
# 12810 427

# %%
target_test = df_test['target'][df_test.groupby('sequence_id').cumcount() == 0].tolist()

# %%
X_test = df_test
y_test = padding_labels(target_test)
# Out:
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
del X_test["sequence_id"] 
del X_test["target"] 

print(len(X_test), len(y_test))
# Out:
# 2580 86

# %%
len(y_train) + len(y_test) == len(df["sequence_id"].unique())
# Out:
# True

# %%
models = Models()

# %%
X_test_flat = models.get_flat_X(X_test)

# %%
X_test = models.get_three_dimensions(X_test)

# %%
X_train_flat = models.get_flat_X(X_train)

# %%
X_train = models.get_three_dimensions(X_train)

# %%
print('Train:', X_train.shape, y_train.shape)
print('Test:', X_test.shape, y_test.shape)
# Out:
# Train: (427, 30, 84) (427, 25)
# Test: (86, 30, 84) (86, 25)

# %% [markdown]
# # Modelo
# La entrada son las coordenadas de las manos. Cada video cuenta con n cantidad de filas, 84 columnas (21 columnas por cada coordenada y por ambas manos).
# La salida es la frase. La frase se representa por un entero que da el one hot encoder.
#
# Se usa convoluciones para resaltar las caracteristicas en la entrada. Debido a que la entrada son coordenadas normalizadas de un video, se supone que funciona igual que si la entrada fuera una imagen. Estas redes extraen caracteristicas de forma automatica para clasificar objetos luego. Al buscar patrones, se espera que pueda predecir un video que ya ha sido entrenado previamente.
#
# Se reduce el tamaño de la entrada haciendo uso de max pooling y flatten.
#
# Se hace uso de Dense para conectar entradas con salidas.
#
# Se hace uso de Dropout para evitar el sobreajuste.
#
# Relu elimina negativos.
# Sigmoid nos ayuda a obtener la probabilidad de que un ejemplo pertenezca a la clase positiva.
# Softmax hace clasificacion multiclase (en nuestro caso las palabras a predecir).

# %%
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(target_train),
                                        y = target_train                                                    
                                    )
class_weights = dict(zip(np.unique(target_train), class_weights))

# %%
cnn_model = Sequential()
cnn_model.add(Convolution2D(128, (3, 3), padding="same", input_shape=(max_seq_length, models.num_features, 1), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

# cnn_model.add(Convolution2D(64, (3, 3), activation='relu'))
# cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

# cnn_model.add(Convolution2D(128, (3, 3), activation='relu'))
# cnn_model.add(MaxPooling2D(pool_size=(2, 2)))


cnn_model.add(Convolution2D(256, (3, 3), padding="same", activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2), strides=2))


cnn_model.add(Flatten())

cnn_model.add(Dense(256, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(len(y_train[1]), activation='softmax'))

# %%
# Compile the model
cnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = cnn_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))
# Get the predictions from the model
y_pred_cnn = cnn_model.predict(X_test)# Find the most likely prediction for each sample

most_likely_predictions = np.argmax(y_pred_cnn, axis=1)
cnn_test_pred = label_encoder.inverse_transform(most_likely_predictions)

test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 54/54 [==============================] - 3s 55ms/step - loss: 3.0270 - accuracy: 0.0960 - val_loss: 2.8392 - val_accuracy: 0.0930
# Epoch 2/50
# 54/54 [==============================] - 3s 51ms/step - loss: 2.1203 - accuracy: 0.3443 - val_loss: 1.8505 - val_accuracy: 0.5581
# Epoch 3/50
# 54/54 [==============================] - 3s 52ms/step - loss: 1.0045 - accuracy: 0.6745 - val_loss: 1.4584 - val_accuracy: 0.6395
# Epoch 4/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.6274 - accuracy: 0.8033 - val_loss: 1.5256 - val_accuracy: 0.6279
# Epoch 5/50
# 54/54 [==============================] - 3s 56ms/step - loss: 0.3665 - accuracy: 0.8876 - val_loss: 1.7326 - val_accuracy: 0.6163
# Epoch 6/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.2798 - accuracy: 0.9040 - val_loss: 1.5884 - val_accuracy: 0.6860
# Epoch 7/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.2301 - accuracy: 0.9297 - val_loss: 1.7230 - val_accuracy: 0.6512
# Epoch 8/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.1870 - accuracy: 0.9321 - val_loss: 1.8765 - val_accuracy: 0.6047
# Epoch 9/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.1464 - accuracy: 0.9532 - val_loss: 1.8246 - val_accuracy: 0.6512
# Epoch 10/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.1698 - accuracy: 0.9461 - val_loss: 1.6119 - val_accuracy: 0.6628
# Epoch 11/50
# 54/54 [==============================] - 3s 50ms/step - loss: 0.1309 - accuracy: 0.9578 - val_loss: 2.4331 - val_accuracy: 0.5930
# Epoch 12/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.1039 - accuracy: 0.9696 - val_loss: 2.1169 - val_accuracy: 0.7093
# Epoch 13/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.1272 - accuracy: 0.9578 - val_loss: 2.7579 - val_accuracy: 0.6047
# Epoch 14/50
# 54/54 [==============================] - 3s 50ms/step - loss: 0.1143 - accuracy: 0.9696 - val_loss: 1.6726 - val_accuracy: 0.6512
# Epoch 15/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0660 - accuracy: 0.9789 - val_loss: 1.9176 - val_accuracy: 0.6279
# Epoch 16/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0547 - accuracy: 0.9766 - val_loss: 1.7086 - val_accuracy: 0.7558
# Epoch 17/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0770 - accuracy: 0.9766 - val_loss: 1.7911 - val_accuracy: 0.7209
# Epoch 18/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.1030 - accuracy: 0.9602 - val_loss: 1.8024 - val_accuracy: 0.7093
# Epoch 19/50
# 54/54 [==============================] - 3s 50ms/step - loss: 0.1011 - accuracy: 0.9672 - val_loss: 2.0189 - val_accuracy: 0.6628
# Epoch 20/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0646 - accuracy: 0.9789 - val_loss: 2.0335 - val_accuracy: 0.5930
# Epoch 21/50
# 54/54 [==============================] - 3s 54ms/step - loss: 0.0712 - accuracy: 0.9766 - val_loss: 1.8308 - val_accuracy: 0.6977
# Epoch 22/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0644 - accuracy: 0.9789 - val_loss: 1.8205 - val_accuracy: 0.6860
# Epoch 23/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0433 - accuracy: 0.9789 - val_loss: 1.9535 - val_accuracy: 0.6860
# Epoch 24/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0588 - accuracy: 0.9813 - val_loss: 3.0699 - val_accuracy: 0.7093
# Epoch 25/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 2.1678 - val_accuracy: 0.7209
# Epoch 26/50
# 54/54 [==============================] - 3s 54ms/step - loss: 0.0325 - accuracy: 0.9883 - val_loss: 2.1422 - val_accuracy: 0.7442
# Epoch 27/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0559 - accuracy: 0.9813 - val_loss: 2.4598 - val_accuracy: 0.6977
# Epoch 28/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0273 - accuracy: 0.9953 - val_loss: 2.3655 - val_accuracy: 0.6860
# Epoch 29/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0340 - accuracy: 0.9906 - val_loss: 2.1369 - val_accuracy: 0.6744
# Epoch 30/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0385 - accuracy: 0.9883 - val_loss: 2.9651 - val_accuracy: 0.6279
# Epoch 31/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.1027 - accuracy: 0.9672 - val_loss: 3.0530 - val_accuracy: 0.6744
# Epoch 32/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0432 - accuracy: 0.9836 - val_loss: 3.3824 - val_accuracy: 0.5814
# Epoch 33/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0673 - accuracy: 0.9789 - val_loss: 2.6546 - val_accuracy: 0.6512
# Epoch 34/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0483 - accuracy: 0.9859 - val_loss: 3.0904 - val_accuracy: 0.6860
# Epoch 35/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0606 - accuracy: 0.9742 - val_loss: 2.7750 - val_accuracy: 0.7093
# Epoch 36/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0634 - accuracy: 0.9789 - val_loss: 2.7763 - val_accuracy: 0.7093
# Epoch 37/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0861 - accuracy: 0.9719 - val_loss: 3.2153 - val_accuracy: 0.6279
# Epoch 38/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 2.9798 - val_accuracy: 0.6163
# Epoch 39/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 2.9970 - val_accuracy: 0.6512
# Epoch 40/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0456 - accuracy: 0.9813 - val_loss: 2.1451 - val_accuracy: 0.6512
# Epoch 41/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0344 - accuracy: 0.9859 - val_loss: 3.1718 - val_accuracy: 0.6512
# Epoch 42/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 2.5551 - val_accuracy: 0.6744
# Epoch 43/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0237 - accuracy: 0.9883 - val_loss: 2.0233 - val_accuracy: 0.6860
# Epoch 44/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 2.0164 - val_accuracy: 0.6860
# Epoch 45/50
# 54/54 [==============================] - 3s 52ms/step - loss: 0.0558 - accuracy: 0.9836 - val_loss: 2.2182 - val_accuracy: 0.6744
# Epoch 46/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 2.4928 - val_accuracy: 0.6860
# Epoch 47/50
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.8504 - val_accuracy: 0.6512
# Epoch 48/50
# 54/54 [==============================] - 3s 51ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 2.6966 - val_accuracy: 0.6744
# Epoch 49/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0328 - accuracy: 0.9859 - val_loss: 3.6350 - val_accuracy: 0.6628
# Epoch 50/50
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0249 - accuracy: 0.9953 - val_loss: 3.0969 - val_accuracy: 0.6744
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 40ms/step - loss: 3.0969 - accuracy: 0.6744
# Test Accuracy: 0.6744186282157898

# %%
# from sklearn.model_selection import GridSearchCV

# # Create the Decision Tree classifier
# dt_classifier = DecisionTreeClassifier()

# # Define the hyperparameters and their possible values
# param_grid = {
#     'base_estimator__max_depth': [len(test_letters) - 1],
#     'base_estimator__min_samples_split': [2, 5, 10],
#     'base_estimator__min_samples_leaf': [1, 2, 4],
#     'base_estimator__max_features': [None, 'auto', 'sqrt', 'log2'],
#     'base_estimator__criterion': ['gini', 'entropy']
# }

# adaboost_model = AdaBoostClassifier(dt_classifier, n_estimators=50, random_state=42)
# # Perform a grid search with cross-validation
# grid_search = GridSearchCV(adaboost_model, param_grid, cv=5, scoring='accuracy')
# grid_search.fit(X_train_flat, target_train)

# # Print the best hyperparameters
# print("Best Decision Tree Hyperparameters:", grid_search.best_params_)
# # Get the best AdaBoost model with the tuned Decision Tree
# best_adaboost_model = grid_search.best_estimator_

# # Evaluate the model on the test set
# accuracy = best_adaboost_model.score(X_test_flat, target_test)
# print("Accuracy on Test Set:", accuracy)
# Out:
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# ...
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:720: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   estimator = estimator.set_params(**cloned_parameters)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 90 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 171, in fit
#     sample_weight, estimator_weight, estimator_error = self._boost(
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 579, in _boost
#     return self._boost_real(iboost, X, y, sample_weight, random_state)
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 588, in _boost_real
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.69581395 0.9225171  0.94150479 0.94385773 0.95310534 0.94383037
#  0.94848153 0.94848153 0.95318741        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.64632011 0.94610123 0.95086183 0.9601368  0.94845417 0.95554036
#  0.94147743 0.94147743 0.96016416 0.60437756 0.9344186  0.94142271
#  0.94377565 0.94377565 0.95075239 0.93674419 0.93674419 0.93904241
#  0.71176471 0.95316005 0.96021888 0.95781122 0.95088919 0.96021888
#  0.95548564 0.95548564 0.95318741        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.6675513  0.96949384 0.95545828 0.955513   0.96722298 0.9601368
#  0.94139535 0.94139535 0.95778386 0.61838577 0.95783858 0.93674419
#  0.93906977 0.94377565 0.94374829 0.94145007 0.94145007 0.93909713]
#   warnings.warn(
# /Users/andreaamaya/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:929: FutureWarning: Parameter 'base_estimator' of AdaBoostClassifier is deprecated in favor of 'estimator'. See AdaBoostClassifier's docstring for more details.
#   clone(base_estimator).set_params(**self.best_params_)
# Best Decision Tree Hyperparameters: {'base_estimator__criterion': 'entropy', 'base_estimator__max_depth': 24, 'base_estimator__max_features': 'sqrt', 'base_estimator__min_samples_leaf': 1, 'base_estimator__min_samples_split': 5}
# Accuracy on Test Set: 0.6976744186046512

# %%
# Create the Decision Tree classifier
dt_classifier = DecisionTreeClassifier()

# Define the hyperparameters and their possible values
param_grid = {
    'base_estimator__max_depth': [len(test_letters) - 1],
    'base_estimator__min_samples_split': [13, 15, 18],
    'base_estimator__min_samples_leaf': [1],
    'base_estimator__max_features': [None],
    'base_estimator__criterion': ['entropy']
}

adaboost_model = AdaBoostClassifier(dt_classifier, n_estimators=50, random_state=42)
# Perform a grid search with cross-validation
grid_search = GridSearchCV(adaboost_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_flat, target_train)

# Print the best hyperparameters
print("Best Decision Tree Hyperparameters:", grid_search.best_params_)
# Get the best AdaBoost model with the tuned Decision Tree
best_adaboost_model = grid_search.best_estimator_

# Evaluate the model on the test set
accuracy = best_adaboost_model.score(X_test_flat, target_test)
print("Accuracy on Test Set:", accuracy)

# %%
# Create the Decision Tree classifier
base_model = DecisionTreeClassifier(
    min_samples_leaf=1, min_samples_split=5, max_depth=len(test_letters) - 1, criterion="entropy", max_features='sqrt'
)
decision_tree = AdaBoostClassifier(
    base_model, n_estimators=300, random_state=42,
    )
decision_tree.fit(X_train_flat, target_train)

# Make predictions
y_pred_tree = decision_tree.predict(X_test_flat)

# Calculate the accuracy score on a test dataset
accuracy_tree = decision_tree.score(X_test_flat, target_test)

# Print the accuracy
print(f'Accuracy: {accuracy_tree:.2f}')
# Out:
# Accuracy: 0.73

# %%
# Create an SVC classifier
svm_classifier = SVC(C=1, kernel="linear", gamma=0.001, class_weight=class_weights)
# Fit the grid search to your training data
svm_classifier.fit(X_train_flat, target_train)
# Evaluate the model on the test data
y_pred_svm = svm_classifier.predict(X_test_flat)

# Calculate the accuracy score on a test dataset
accuracy_svm = svm_classifier.score(X_test_flat, target_test)

# Print the accuracy
print(f'Accuracy: {accuracy_svm:.2f}')
# Out:
# Accuracy: 0.56

# %% [markdown]
# # Guardando los modelos

# %%
cnn_model.save('cnn_asl')
models.save_model("tree_asl", decision_tree)
models.save_model("svm_asl", svm_classifier)
# Out:
# INFO:tensorflow:Assets written to: cnn_asl/assets
# INFO:tensorflow:Assets written to: cnn_asl/assets

# %%
models.save_model("label_encoder_asl", label_encoder)

# %% [markdown]
# # Usando los tres modelos

# %%
pretainedModels = PretrainedModels(is_asl=True)
results = pretainedModels.get_predictions(df_test)
results = pretainedModels.get_unique_pred()
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step

# %%
correct = 0
for i in range(len(target_test)):
    if (target_test[i] in results[i]):
        correct += 1
    else:
        print(">>> LOG INCORRECTA: ")
        print("            Predicho: ", results[i])
        print("            Correcto: ", target_test[i])
# Out:
# >>> LOG INCORRECTA:
#             Predicho:  ['dog', 'yes']
#             Correcto:  see you later
# >>> LOG INCORRECTA:
#             Predicho:  ['finish', 'learn']
#             Correcto:  sign
# >>> LOG INCORRECTA:
#             Predicho:  ['sign']
#             Correcto:  what
# >>> LOG INCORRECTA:
#             Predicho:  ['repeat', 'sign', 'please']
#             Correcto:  help
# >>> LOG INCORRECTA:
#             Predicho:  ['no', 'milk']
#             Correcto:  see you later
# >>> LOG INCORRECTA:
#             Predicho:  ['sign', 'learn']
#             Correcto:  repeat
# >>> LOG INCORRECTA:
#             Predicho:  ['finish', 'learn']
#             Correcto:  more
# >>> LOG INCORRECTA:
#             Predicho:  ['finish', 'bathroom', 'learn']
#             Correcto:  sign
# >>> LOG INCORRECTA:
#             Predicho:  ['want', 'sign']
#             Correcto:  what
# >>> LOG INCORRECTA:
#             Predicho:  ['sign', 'learn']
#             Correcto:  repeat
# >>> LOG INCORRECTA:
#             Predicho:  ['finish', 'learn']
#             Correcto:  more
# >>> LOG INCORRECTA:
#             Predicho:  ['fine']
#             Correcto:  father
# >>> LOG INCORRECTA:
#             Predicho:  ['sign', 'learn']
#             Correcto:  repeat
# >>> LOG INCORRECTA:
#             Predicho:  ['father']
#             Correcto:  fine

# %%
print("Correct >> ", correct)
print("Incorrect >> ", len(target_test)-correct)
print("Ratio >> ", str(correct/len(target_test)))
# Out:
# Correct >>  72
# Incorrect >>  14
# Ratio >>  0.8372093023255814

# %% [markdown]
# # Reutilizando los tres modelos

# %%
load_test_data = pd.read_csv("data/asl/data_tests.csv")
load_test_data.head()
# Out:
#    sequence_id  target                                               file  \
# 0            1  2_sign  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 1            1  2_sign  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 2            1  2_sign  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 3            1  2_sign  /Users/andreaamaya/Trabajo/megaproyecto_model/...
# 4            1  2_sign  /Users/andreaamaya/Trabajo/megaproyecto_model/...
#
#    x_Left_hand_0  y_Left_hand_0  x_Left_hand_1  y_Left_hand_1  x_Left_hand_2  \
# 0       0.779944       0.857275       0.527943       0.674595       0.338587
# 1       1.000000       0.105118       0.738827       0.019696       0.554572
# 2       1.000000       0.049991       0.772897       0.000000       0.591776
# 3       1.000000       0.060846       0.767145       0.000000       0.569186
# 4       1.000000       0.016505       0.763875       0.000000       0.550771
#
#    y_Left_hand_2  x_Left_hand_3  ...  x_Right_hand_16  y_Right_hand_16  \
# 0       0.450659       0.242364  ...         0.000000         0.000000
# 1       0.011717       0.435643  ...         0.146080         0.462339
# 2       0.041368       0.466249  ...         0.301188         0.352286
# 3       0.068999       0.435114  ...         0.297766         0.299877
# 4       0.109922       0.404051  ...         0.293271         0.324966
#
#    x_Right_hand_17  y_Right_hand_17  x_Right_hand_18  y_Right_hand_18  \
# 0         0.000000         0.000000         0.000000         0.000000
# 1         0.009484         0.677178         0.062564         0.199427
# 2         0.299280         0.947524         0.340257         0.324660
# 3         0.327299         0.965769         0.358205         0.424474
# 4         0.339481         1.000000         0.368824         0.479093
#
#    x_Right_hand_19  y_Right_hand_19  x_Right_hand_20  y_Right_hand_20
# 0         0.000000         0.000000         0.000000         0.000000
# 1         0.016843         0.299629         0.000000         0.464140
# 2         0.261477         0.309198         0.221117         0.485982
# 3         0.283723         0.333584         0.243731         0.450707
# 4         0.292869         0.368690         0.246684         0.459646
#
# [5 rows x 87 columns]

# %%
target = load_test_data["target"]

# %%
del load_test_data["sequence_id"] 
del load_test_data["target"] 
del load_test_data["file"]

# %%
pretainedModels = PretrainedModels(is_asl=True)
results = pretainedModels.get_predictions(load_test_data)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
expected = target.unique()
expected
# Out:
# array(['2_sign', '3_like', '13_see you later', '11_father', '14_hello',
#        '6_thank you', '4_bathroom', '7_please', '9_no', '12_me', '10_yes',
#        '8_help', '5_eat food', '1_finish'], dtype=object)

# %%
results = pretainedModels.get_unique_pred()
results
# Out:
# [['go to', 'learn'],
#  ['like'],
#  ['see you later'],
#  ['fine'],
#  ['hello'],
#  ['thank you'],
#  ['bathroom'],
#  ['please'],
#  ['no', 'milk', 'fine'],
#  ['me'],
#  ['yes'],
#  ['want', 'repeat', 'learn'],
#  ['eat food'],
#  ['dog', 'sign']]

# %%
correct = 0
for i in range(len(results)):
    if (expected[i].split("_")[1] in results[i]):
        correct += 1
    else:
        print(f'Palabras incorrecta: {expected[i].split("_")[1]} predijo {results[i]}')
# Out:
# Palabras incorrecta: sign predijo ['go to', 'learn']
# Palabras incorrecta: father predijo ['fine']
# Palabras incorrecta: help predijo ['want', 'repeat', 'learn']
# Palabras incorrecta: finish predijo ['dog', 'sign']

# %%
print(f'Palabras correctas: {correct} de {len(results)}')
# Out:
# Palabras correctas: 10 de 14
